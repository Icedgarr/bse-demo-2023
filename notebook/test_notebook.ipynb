# %%
import pandas as pd
from bse_demo_library.features.compute_death_rate import compute_death_rate

# %%
data = pd.read_csv('../covid.csv')

# %%
data
# Out:
#                 Country  Confirmed  Deaths  Recovered  Active
# 0           Afghanistan        120       4          2     114
# 1               Albania        212      10         33     169
# 2               Algeria        511      31         31     449
# 3               Andorra        334       6          1     327
# 4                Angola          7       2          0       5
# ..                  ...        ...     ...        ...     ...
# 172           Venezuela        119       2         39      78
# 173             Vietnam        188       0         25     163
# 174  West Bank and Gaza        109       1         18      90
# 175              Zambia         29       0          0      29
# 176            Zimbabwe          7       1          0       6
#
# [177 rows x 5 columns]

# %%
compute_death_rate(data)
# Out:
#                 Country  Confirmed  Deaths  Recovered  Active  death_rate
# 0           Afghanistan        120       4          2     114    0.035088
# 1               Albania        212      10         33     169    0.059172
# 2               Algeria        511      31         31     449    0.069042
# 3               Andorra        334       6          1     327    0.018349
# 4                Angola          7       2          0       5    0.400000
# ..                  ...        ...     ...        ...     ...         ...
# 172           Venezuela        119       2         39      78    0.025641
# 173             Vietnam        188       0         25     163    0.000000
# 174  West Bank and Gaza        109       1         18      90    0.011111
# 175              Zambia         29       0          0      29    0.000000
# 176            Zimbabwe          7       1          0       6    0.166667
#
# [177 rows x 6 columns]
